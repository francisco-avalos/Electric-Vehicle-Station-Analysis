# %%
import pandas as pd
from datetime import datetime

# %%
# !cd
# Out:
# C:\Users\francisco.avalos\Desktop\thesis

# %%
df = pd.read_csv('C:/Users/francisco.avalos/Desktop/thesis/data/LA_2019_20.csv')
# Out:
# C:\Users\francisco.avalos\.conda\envs\thesis-env\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,6,7,8,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
one_df = df.loc[df['station_id']==295]

# %%
# one_df.head(75)

# %%
# one_df.dtypes
df.head()
# Out:
#      flowdate  station_id  station_latitude  station_longitude  \
# 0  2019-01-01           9           32.9815          -117.2525
# 1  2019-01-02           9           32.9815          -117.2525
# 2  2019-01-03           9           32.9815          -117.2525
# 3  2019-01-04           9           32.9815          -117.2525
# 4  2019-01-05           9           32.9815          -117.2525
#
#   charger_company_col im_date im_start single_im_day im_end  minutes_diff  \
# 0              NISSAN     NaN      NaN           NaN    NaN           NaN
# 1              NISSAN     NaN      NaN           NaN    NaN           NaN
# 2              NISSAN     NaN      NaN           NaN    NaN           NaN
# 3              NISSAN     NaN      NaN           NaN    NaN           NaN
# 4              NISSAN     NaN      NaN           NaN    NaN           NaN
#
#   target_start_date target_end_date session_start_date  sessions  minutes  \
# ...

# %%
df['im_date'] = pd.to_datetime(df['im_date'])
df['im_start'] = pd.to_datetime(df['im_start'], format = '%Y-%m-%d %H:%M:%S')
df['single_im_day'] = pd.to_datetime(df['single_im_day'])
df['im_end'] = pd.to_datetime(df['im_end'], format = '%Y-%m-%d %H:%M:%S', errors='ignore')
df['target_start_date'] = pd.to_datetime(df['target_start_date'])
df['target_end_date'] = pd.to_datetime(df['target_end_date'])
df['session_start_date'] = pd.to_datetime(df['session_start_date'])

# %%
df.info()
# one_df['im_start'].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426330 entries, 0 to 1426329
# Data columns (total 17 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   flowdate             1426330 non-null  object
#  1   station_id           1426330 non-null  int64
#  2   station_latitude     713391 non-null   float64
#  3   station_longitude    713391 non-null   float64
#  4   charger_company_col  1426330 non-null  object
#  5   im_date              28736 non-null    datetime64[ns]
#  6   im_start             28736 non-null    datetime64[ns]
#  7   single_im_day        791 non-null      datetime64[ns]
#  8   im_end               28736 non-null    object
#  9   minutes_diff         28680 non-null    float64
#  10  target_start_date    360469 non-null   datetime64[ns]
#  11  target_end_date      368233 non-null   datetime64[ns]
#  12  session_start_date   713391 non-null   datetime64[ns]
# ...

# %%
# one_df.tail(75)
# pd.isnull(df.loc[(df['flowdate']=='2020-10-01') & (df['station_id']==295)])
pd.isnull(df.loc[(df['flowdate']=='2019-10-01') & (df['station_id']==9)]['im_start'])
# Out:
# 273    True
# Name: im_start, dtype: bool

# %%
df.head()
# Out:
#      flowdate  station_id  station_latitude  station_longitude  \
# 0  2019-01-01           9           32.9815          -117.2525
# 1  2019-01-02           9           32.9815          -117.2525
# 2  2019-01-03           9           32.9815          -117.2525
# 3  2019-01-04           9           32.9815          -117.2525
# 4  2019-01-05           9           32.9815          -117.2525
#
#   charger_company_col im_date im_start single_im_day im_end  minutes_diff  \
# 0              NISSAN     NaT      NaT           NaT    NaN           NaN
# 1              NISSAN     NaT      NaT           NaT    NaN           NaN
# 2              NISSAN     NaT      NaT           NaT    NaN           NaN
# 3              NISSAN     NaT      NaT           NaT    NaN           NaN
# 4              NISSAN     NaT      NaT           NaT    NaN           NaN
#
#   target_start_date target_end_date session_start_date  sessions  minutes  \
# ...

# %%
rangelist = df['station_id'].unique()

# %%
for i in rangelist:
#     df_sub_rows = df.loc[df['station_id']==i].shape[0]
    station_info_df = df.loc[df['station_id']==i]
    station_min_day = station_info_df['flowdate'].min()
    station_max_day = station_info_df['flowdate'].max()
    print(i, ' ', df_sub_rows)
# Out:
# 9   731
# 11   731
# 14   119
# 15   731
# 17   731
# 20   693
# 21   731
# 23   731
# 25   731
# 26   731
# 27   731
# 31   731
# 34   731
# 38   731
# 39   731
# 50   731
# 53   731
# 54   731
# 55   731
# 56   731
# 57   674
# 62   731
# 65   731
# 66   731
# 67   731
# 68   731
# 69   731
# 72   731
# 73   731
# 74   731
# 75   731
# 78   731
# 79   731
# 83   731
# 85   731
# 90   731
# 91   731
# 93   731
# 94   731
# 98   317
# 102   731
# 103   731
# 104   731
# 105   731
# 106   731
# 107   731
# 108   731
# 109   731
# 110   731
# 111   731
# 112   731
# 113   731
# 114   731
# 115   731
# 116   731
# 118   731
# 119   731
# 120   731
# 121   731
# 122   731
# 123   731
# 124   731
# 125   731
# 126   731
# 127   731
# 128   731
# 129   731
# 130   731
# 131   731
# 132   731
# 133   731
# 134   731
# 135   731
# 136   731
# 137   731
# 138   731
# 139   731
# 140   731
# 141   731
# 142   731
# 143   515
# 144   731
# 146   731
# 147   731
# 148   731
# 149   731
# ...

# %%
# df.loc[df['station_id']==53999]
df.loc[df['station_id']==53999]['flowdate'].max()
# Out:
# '2020-12-31'

# %%
station_info_df = df.loc[df['station_id']==i]

# %%
    station_min_day = station_info_df['flowdate'].min()
    station_max_day = station_info_df['flowdate'].max()

# %%
station_min_day
# Out:
# '2020-12-30'

# %%
station_max_day
# Out:
# '2020-12-31'
